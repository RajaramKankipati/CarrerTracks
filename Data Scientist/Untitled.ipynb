# %%
import numpy as np

# %%
# %timeit np.random.rand(1000)
# Out:
# 8.45 µs ± 125 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit -r2 -n10 np.random.rand(1000)
# Out:
# 32.2 µs ± 16.4 µs per loop (mean ± std. dev. of 2 runs, 10 loops each)

# %%
pip install line_profiler
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Complete output from command C:\Users\i332835\AppData\Local\Continuum\anaconda3\python.exe C:\Users\i332835\AppData\Local\Continuum\anaconda3\lib\site-packages\pip\_vendor\pep517\_in_process.py build_wheel C:\Users\i332835\AppData\Local\Temp\tmpcyudn6yh:
#   Not searching for unused variables given on the command line.
#   -- The C compiler identification is unknown
#   CMake Error at CMakeLists.txt:3 (ENABLE_LANGUAGE):
#     No CMAKE_C_COMPILER could be found.
#
# ...
